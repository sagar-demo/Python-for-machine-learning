# %%
# !pip install modin[ray]
# Out:
# Requirement already satisfied: modin[ray] in c:\anaconda3\lib\site-packages (0.8.3)
# Requirement already satisfied: packaging in c:\anaconda3\lib\site-packages (from modin[ray]) (20.8)
# Requirement already satisfied: pandas==1.1.5 in c:\anaconda3\lib\site-packages (from modin[ray]) (1.1.5)
# Collecting modin[ray]
#   Downloading modin-0.8.2-py3-none-win32.whl (533 kB)
#   Downloading modin-0.8.1.1-py3-none-win32.whl (538 kB)
#   Downloading modin-0.8.1-py3-none-win32.whl (537 kB)
#   Downloading modin-0.8.0-py3-none-win32.whl (387 kB)
#   Downloading modin-0.7.4-py3-none-win32.whl (334 kB)
#   Downloading modin-0.7.3-py3-none-win32.whl (301 kB)
#   Downloading modin-0.7.2-py3-none-any.whl (242 kB)
#   Downloading modin-0.7.1-py3-none-any.whl (243 kB)
#   Downloading modin-0.7.0-py3-none-any.whl (241 kB)
#   Downloading modin-0.6.3-py3-none-any.whl (234 kB)
#   Downloading modin-0.6.2-py3-none-any.whl (231 kB)
#   Downloading modin-0.6.1-py3-none-any.whl (230 kB)
#   Downloading modin-0.6.0-py3-none-any.whl (227 kB)
#   Downloading modin-0.5.4-py3-none-any.whl (228 kB)
#   Downloading modin-0.5.3-py3-none-any.whl (218 kB)
#   Downloading modin-0.5.2-py3-none-any.whl (216 kB)
#   Downloading modin-0.5.1-py3-none-any.whl (216 kB)
#   Downloading modin-0.5.0-py3-none-any.whl (213 kB)
#   Downloading modin-0.4.0-py3-none-any.whl (184 kB)
#   Downloading modin-0.3.1-py3-none-any.whl (164 kB)
#   Downloading modin-0.3.0-py3-none-any.whl (154 kB)
#   Downloading modin-0.2.5-py3-none-any.whl (133 kB)
#   Downloading modin-0.2.4-py3-none-any.whl (130 kB)
#   Downloading modin-0.2.3-py3-none-any.whl (131 kB)
#   Downloading modin-0.2.2-py3-none-any.whl (130 kB)
#   Downloading modin-0.2.0-py3-none-any.whl (115 kB)
#   Downloading modin-0.1.2-py3-none-any.whl (104 kB)
#   Downloading modin-0.1.1-py3-none-any.whl (102 kB)
#   Downloading modin-0.1.0-py3-none-any.whl (173 kB)
#   Downloading modin-0.0.2-py3-none-any.whl (97 kB)
# Collecting pandas==0.22
#   Downloading pandas-0.22.0.tar.gz (11.3 MB)
#   Installing build dependencies: started
#   Installing build dependencies: still running...
#   Installing build dependencies: finished with status 'error'
# WARNING: modin 0.6.0 does not provide the extra 'ray'
# WARNING: modin 0.5.4 does not provide the extra 'ray'
# WARNING: modin 0.5.3 does not provide the extra 'ray'
# WARNING: modin 0.5.2 does not provide the extra 'ray'
# WARNING: modin 0.5.1 does not provide the extra 'ray'
# WARNING: modin 0.5.0 does not provide the extra 'ray'
# WARNING: modin 0.4.0 does not provide the extra 'ray'
# WARNING: modin 0.3.1 does not provide the extra 'ray'
# WARNING: modin 0.3.0 does not provide the extra 'ray'
# WARNING: modin 0.2.5 does not provide the extra 'ray'
# WARNING: modin 0.2.4 does not provide the extra 'ray'
# WARNING: modin 0.2.3 does not provide the extra 'ray'
# WARNING: modin 0.2.2 does not provide the extra 'ray'
# WARNING: modin 0.2.0 does not provide the extra 'ray'
# WARNING: modin 0.1.2 does not provide the extra 'ray'
# WARNING: modin 0.1.1 does not provide the extra 'ray'
# WARNING: modin 0.1.0 does not provide the extra 'ray'
# WARNING: modin 0.0.2 does not provide the extra 'ray'
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\anaconda3\python.exe' 'C:\anaconda3\lib\site-packages\pip' install --ignore-installed --no-user --prefix 'C:\Users\91744\AppData\Local\Temp\pip-build-env-3y1snzkr\overlay' --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- wheel setuptools Cython 'numpy==1.9.3; python_version=='"'"'3.5'"'"'' 'numpy==1.12.1; python_version=='"'"'3.6'"'"'' 'numpy==1.13.1; python_version>='"'"'3.7'"'"''
#        cwd: None
#   Complete output (363 lines):
#   Ignoring numpy: markers 'python_version == "3.5"' don't match your environment
#   Ignoring numpy: markers 'python_version == "3.6"' don't match your environment
#   Collecting numpy==1.13.1
#     Downloading numpy-1.13.1.zip (5.0 MB)
#   Collecting Cython
#     Using cached Cython-0.29.21-cp38-cp38-win32.whl (1.6 MB)
#   Collecting wheel
#     Using cached wheel-0.36.2-py2.py3-none-any.whl (35 kB)
#   Collecting setuptools
#     Downloading setuptools-51.3.3-py3-none-any.whl (786 kB)
#   Building wheels for collected packages: numpy
#     Building wheel for numpy (setup.py): started
#     Building wheel for numpy (setup.py): finished with status 'error'
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\anaconda3\python.exe' -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\91744\\AppData\\Local\\Temp\\pip-install-jv4156t0\\numpy_d5224f203bde424bbe44872392394839\\setup.py'"'"'; __file__='"'"'C:\\Users\\91744\\AppData\\Local\\Temp\\pip-install-jv4156t0\\numpy_d5224f203bde424bbe44872392394839\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\91744\AppData\Local\Temp\pip-wheel-1qi681a9'
#          cwd: C:\Users\91744\AppData\Local\Temp\pip-install-jv4156t0\numpy_d5224f203bde424bbe44872392394839\
#     Complete output (157 lines):
#     Running from numpy source directory.
#     C:\Users\91744\AppData\Local\Temp\pip-install-jv4156t0\numpy_d5224f203bde424bbe44872392394839\numpy\distutils\misc_util.py:469: SyntaxWarning: "is" with a literal. Did you mean "=="?
#       return is_string(s) and ('*' in s or '?' is s)
#     blas_opt_info:
#     blas_mkl_info:
#       libraries mkl_rt not found in ['C:\\anaconda3\\lib', 'C:\\', 'C:\\anaconda3\\libs']
#       NOT AVAILABLE
#
#     blis_info:
#       libraries blis not found in ['C:\\anaconda3\\lib', 'C:\\', 'C:\\anaconda3\\libs']
#       NOT AVAILABLE
#
#     openblas_info:
#       libraries openblas not found in ['C:\\anaconda3\\lib', 'C:\\', 'C:\\anaconda3\\libs']
#       NOT AVAILABLE
#
#     atlas_3_10_blas_threads_info:
#     Setting PTATLAS=ATLAS
#       libraries tatlas not found in ['C:\\anaconda3\\lib', 'C:\\', 'C:\\anaconda3\\libs']
#       NOT AVAILABLE
#
#     atlas_3_10_blas_info:
#       libraries satlas not found in ['C:\\anaconda3\\lib', 'C:\\', 'C:\\anaconda3\\libs']
#       NOT AVAILABLE
#
#     atlas_blas_threads_info:
#     Setting PTATLAS=ATLAS
#       libraries ptf77blas,ptcblas,atlas not found in ['C:\\anaconda3\\lib', 'C:\\', 'C:\\anaconda3\\libs']
#       NOT AVAILABLE
#
#     atlas_blas_info:
#       libraries f77blas,cblas,atlas not found in ['C:\\anaconda3\\lib', 'C:\\', 'C:\\anaconda3\\libs']
#       NOT AVAILABLE
#
#     C:\Users\91744\AppData\Local\Temp\pip-install-jv4156t0\numpy_d5224f203bde424bbe44872392394839\numpy\distutils\system_info.py:572: UserWarning:
#         Atlas (http://math-atlas.sourceforge.net/) libraries not found.
#         Directories to search for the libraries can be specified in the
#         numpy/distutils/site.cfg file (section [atlas]) or by setting
#         the ATLAS environment variable.
#       self.calc_info()
#     blas_info:
#       libraries blas not found in ['C:\\anaconda3\\lib', 'C:\\', 'C:\\anaconda3\\libs']
#       NOT AVAILABLE
#
#     C:\Users\91744\AppData\Local\Temp\pip-install-jv4156t0\numpy_d5224f203bde424bbe44872392394839\numpy\distutils\system_info.py:572: UserWarning:
#         Blas (http://www.netlib.org/blas/) libraries not found.
#         Directories to search for the libraries can be specified in the
#         numpy/distutils/site.cfg file (section [blas]) or by setting
#         the BLAS environment variable.
#       self.calc_info()
#     blas_src_info:
#       NOT AVAILABLE
#
#     C:\Users\91744\AppData\Local\Temp\pip-install-jv4156t0\numpy_d5224f203bde424bbe44872392394839\numpy\distutils\system_info.py:572: UserWarning:
#         Blas (http://www.netlib.org/blas/) sources not found.
#         Directories to search for the sources can be specified in the
#         numpy/distutils/site.cfg file (section [blas_src]) or by setting
#         the BLAS_SRC environment variable.
#       self.calc_info()
#       NOT AVAILABLE
#
#     'svnversion' is not recognized as an internal or external command,
#     operable program or batch file.
#     'svnversion' is not recognized as an internal or external command,
#     operable program or batch file.
#     non-existing path in 'numpy\\distutils': 'site.cfg'
#     F2PY Version 2
#     lapack_opt_info:
#     lapack_mkl_info:
#       libraries mkl_rt not found in ['C:\\anaconda3\\lib', 'C:\\', 'C:\\anaconda3\\libs']
#       NOT AVAILABLE
#
#     openblas_lapack_info:
#       libraries openblas not found in ['C:\\anaconda3\\lib', 'C:\\', 'C:\\anaconda3\\libs']
#       NOT AVAILABLE
#
#     atlas_3_10_threads_info:
#     Setting PTATLAS=ATLAS
#       libraries tatlas,tatlas not found in C:\anaconda3\lib
#       libraries lapack_atlas not found in C:\anaconda3\lib
#       libraries tatlas,tatlas not found in C:\
#       libraries lapack_atlas not found in C:\
#       libraries tatlas,tatlas not found in C:\anaconda3\libs
#       libraries lapack_atlas not found in C:\anaconda3\libs
#     <class 'numpy.distutils.system_info.atlas_3_10_threads_info'>
#       NOT AVAILABLE
#
#     atlas_3_10_info:
#       libraries satlas,satlas not found in C:\anaconda3\lib
#       libraries lapack_atlas not found in C:\anaconda3\lib
#       libraries satlas,satlas not found in C:\
#       libraries lapack_atlas not found in C:\
#       libraries satlas,satlas not found in C:\anaconda3\libs
#       libraries lapack_atlas not found in C:\anaconda3\libs
#     <class 'numpy.distutils.system_info.atlas_3_10_info'>
#       NOT AVAILABLE
#
#     atlas_threads_info:
#     Setting PTATLAS=ATLAS
#       libraries ptf77blas,ptcblas,atlas not found in C:\anaconda3\lib
#       libraries lapack_atlas not found in C:\anaconda3\lib
#       libraries ptf77blas,ptcblas,atlas not found in C:\
#       libraries lapack_atlas not found in C:\
#       libraries ptf77blas,ptcblas,atlas not found in C:\anaconda3\libs
#       libraries lapack_atlas not found in C:\anaconda3\libs
#     <class 'numpy.distutils.system_info.atlas_threads_info'>
#       NOT AVAILABLE
#
#     atlas_info:
#       libraries f77blas,cblas,atlas not found in C:\anaconda3\lib
#       libraries lapack_atlas not found in C:\anaconda3\lib
#       libraries f77blas,cblas,atlas not found in C:\
#       libraries lapack_atlas not found in C:\
#       libraries f77blas,cblas,atlas not found in C:\anaconda3\libs
#       libraries lapack_atlas not found in C:\anaconda3\libs
#     <class 'numpy.distutils.system_info.atlas_info'>
#       NOT AVAILABLE
#
#     lapack_info:
#       libraries lapack not found in ['C:\\anaconda3\\lib', 'C:\\', 'C:\\anaconda3\\libs']
#       NOT AVAILABLE
#
#     C:\Users\91744\AppData\Local\Temp\pip-install-jv4156t0\numpy_d5224f203bde424bbe44872392394839\numpy\distutils\system_info.py:572: UserWarning:
#         Lapack (http://www.netlib.org/lapack/) libraries not found.
#         Directories to search for the libraries can be specified in the
#         numpy/distutils/site.cfg file (section [lapack]) or by setting
#         the LAPACK environment variable.
#       self.calc_info()
#     lapack_src_info:
#       NOT AVAILABLE
#
#     C:\Users\91744\AppData\Local\Temp\pip-install-jv4156t0\numpy_d5224f203bde424bbe44872392394839\numpy\distutils\system_info.py:572: UserWarning:
#         Lapack (http://www.netlib.org/lapack/) sources not found.
#         Directories to search for the sources can be specified in the
#         numpy/distutils/site.cfg file (section [lapack_src]) or by setting
#         the LAPACK_SRC environment variable.
#       self.calc_info()
#       NOT AVAILABLE
#
#     C:\anaconda3\lib\distutils\dist.py:274: UserWarning: Unknown distribution option: 'define_macros'
#       warnings.warn(msg)
#     running bdist_wheel
#     running build
#     running config_cc
#     unifing config_cc, config, build_clib, build_ext, build commands --compiler options
#     running config_fc
#     unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
#     running build_src
#     build_src
#     building py_modules sources
#     creating build
#     creating build\src.win32-3.8
#     creating build\src.win32-3.8\numpy
#     creating build\src.win32-3.8\numpy\distutils
#     building library "npymath" sources
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#     ----------------------------------------
#     ERROR: Failed building wheel for numpy
#     Running setup.py clean for numpy
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\anaconda3\python.exe' -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\91744\\AppData\\Local\\Temp\\pip-install-jv4156t0\\numpy_d5224f203bde424bbe44872392394839\\setup.py'"'"'; __file__='"'"'C:\\Users\\91744\\AppData\\Local\\Temp\\pip-install-jv4156t0\\numpy_d5224f203bde424bbe44872392394839\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' clean --all
#          cwd: C:\Users\91744\AppData\Local\Temp\pip-install-jv4156t0\numpy_d5224f203bde424bbe44872392394839
#     Complete output (10 lines):
#     Running from numpy source directory.
#
#     `setup.py clean` is not supported, use one of the following instead:
#
#       - `git clean -xdf` (cleans all files)
#       - `git clean -Xdf` (cleans all versioned files, doesn't touch
#                           files that aren't checked into the git repo)
#
#     Add `--force` to your command to use it anyway if you must (unsupported).
#
#     ----------------------------------------
#     ERROR: Failed cleaning build dir for numpy
#   Failed to build numpy
#   Installing collected packages: wheel, setuptools, numpy, Cython
#       Running setup.py install for numpy: started
#       Running setup.py install for numpy: finished with status 'error'
#       ERROR: Command errored out with exit status 1:
#        command: 'C:\anaconda3\python.exe' -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\91744\\AppData\\Local\\Temp\\pip-install-jv4156t0\\numpy_d5224f203bde424bbe44872392394839\\setup.py'"'"'; __file__='"'"'C:\\Users\\91744\\AppData\\Local\\Temp\\pip-install-jv4156t0\\numpy_d5224f203bde424bbe44872392394839\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\91744\AppData\Local\Temp\pip-record-zc_ei1pt\install-record.txt' --single-version-externally-managed --prefix 'C:\Users\91744\AppData\Local\Temp\pip-build-env-3y1snzkr\overlay' --compile --install-headers 'C:\Users\91744\AppData\Local\Temp\pip-build-env-3y1snzkr\overlay\Include\numpy'
#            cwd: C:\Users\91744\AppData\Local\Temp\pip-install-jv4156t0\numpy_d5224f203bde424bbe44872392394839\
#       Complete output (160 lines):
#       Running from numpy source directory.
#
#       Note: if you need reliable uninstall behavior, then install
#       with pip instead of using `setup.py install`:
#
#         - `pip install .`       (from a git repo or downloaded source
#                                  release)
#         - `pip install numpy`   (last NumPy release on PyPi)
#
#
#       blas_opt_info:
#       blas_mkl_info:
#         libraries mkl_rt not found in ['C:\\anaconda3\\lib', 'C:\\', 'C:\\anaconda3\\libs']
#         NOT AVAILABLE
#
#       blis_info:
#         libraries blis not found in ['C:\\anaconda3\\lib', 'C:\\', 'C:\\anaconda3\\libs']
#         NOT AVAILABLE
#
#       openblas_info:
#         libraries openblas not found in ['C:\\anaconda3\\lib', 'C:\\', 'C:\\anaconda3\\libs']
#         NOT AVAILABLE
#
#       atlas_3_10_blas_threads_info:
#       Setting PTATLAS=ATLAS
#         libraries tatlas not found in ['C:\\anaconda3\\lib', 'C:\\', 'C:\\anaconda3\\libs']
#         NOT AVAILABLE
#
#       atlas_3_10_blas_info:
#         libraries satlas not found in ['C:\\anaconda3\\lib', 'C:\\', 'C:\\anaconda3\\libs']
#         NOT AVAILABLE
#
#       atlas_blas_threads_info:
#       Setting PTATLAS=ATLAS
#         libraries ptf77blas,ptcblas,atlas not found in ['C:\\anaconda3\\lib', 'C:\\', 'C:\\anaconda3\\libs']
#         NOT AVAILABLE
#
#       atlas_blas_info:
#         libraries f77blas,cblas,atlas not found in ['C:\\anaconda3\\lib', 'C:\\', 'C:\\anaconda3\\libs']
#         NOT AVAILABLE
#
#       C:\Users\91744\AppData\Local\Temp\pip-install-jv4156t0\numpy_d5224f203bde424bbe44872392394839\numpy\distutils\system_info.py:572: UserWarning:
#           Atlas (http://math-atlas.sourceforge.net/) libraries not found.
#           Directories to search for the libraries can be specified in the
#           numpy/distutils/site.cfg file (section [atlas]) or by setting
#           the ATLAS environment variable.
#         self.calc_info()
#       blas_info:
#         libraries blas not found in ['C:\\anaconda3\\lib', 'C:\\', 'C:\\anaconda3\\libs']
#         NOT AVAILABLE
#
#       C:\Users\91744\AppData\Local\Temp\pip-install-jv4156t0\numpy_d5224f203bde424bbe44872392394839\numpy\distutils\system_info.py:572: UserWarning:
#           Blas (http://www.netlib.org/blas/) libraries not found.
#           Directories to search for the libraries can be specified in the
#           numpy/distutils/site.cfg file (section [blas]) or by setting
#           the BLAS environment variable.
#         self.calc_info()
#       blas_src_info:
#         NOT AVAILABLE
#
#       C:\Users\91744\AppData\Local\Temp\pip-install-jv4156t0\numpy_d5224f203bde424bbe44872392394839\numpy\distutils\system_info.py:572: UserWarning:
#           Blas (http://www.netlib.org/blas/) sources not found.
#           Directories to search for the sources can be specified in the
#           numpy/distutils/site.cfg file (section [blas_src]) or by setting
#           the BLAS_SRC environment variable.
#         self.calc_info()
#         NOT AVAILABLE
#
#       'svnversion' is not recognized as an internal or external command,
#       operable program or batch file.
#       'svnversion' is not recognized as an internal or external command,
#       operable program or batch file.
#       non-existing path in 'numpy\\distutils': 'site.cfg'
#       F2PY Version 2
#       lapack_opt_info:
#       lapack_mkl_info:
#         libraries mkl_rt not found in ['C:\\anaconda3\\lib', 'C:\\', 'C:\\anaconda3\\libs']
#         NOT AVAILABLE
#
#       openblas_lapack_info:
#         libraries openblas not found in ['C:\\anaconda3\\lib', 'C:\\', 'C:\\anaconda3\\libs']
#         NOT AVAILABLE
#
#       atlas_3_10_threads_info:
#       Setting PTATLAS=ATLAS
#         libraries tatlas,tatlas not found in C:\anaconda3\lib
#         libraries lapack_atlas not found in C:\anaconda3\lib
#         libraries tatlas,tatlas not found in C:\
#         libraries lapack_atlas not found in C:\
#         libraries tatlas,tatlas not found in C:\anaconda3\libs
#         libraries lapack_atlas not found in C:\anaconda3\libs
#       <class 'numpy.distutils.system_info.atlas_3_10_threads_info'>
#         NOT AVAILABLE
#
#       atlas_3_10_info:
#         libraries satlas,satlas not found in C:\anaconda3\lib
#         libraries lapack_atlas not found in C:\anaconda3\lib
#         libraries satlas,satlas not found in C:\
#         libraries lapack_atlas not found in C:\
#         libraries satlas,satlas not found in C:\anaconda3\libs
#         libraries lapack_atlas not found in C:\anaconda3\libs
#       <class 'numpy.distutils.system_info.atlas_3_10_info'>
#         NOT AVAILABLE
#
#       atlas_threads_info:
#       Setting PTATLAS=ATLAS
#         libraries ptf77blas,ptcblas,atlas not found in C:\anaconda3\lib
#         libraries lapack_atlas not found in C:\anaconda3\lib
#         libraries ptf77blas,ptcblas,atlas not found in C:\
#         libraries lapack_atlas not found in C:\
#         libraries ptf77blas,ptcblas,atlas not found in C:\anaconda3\libs
#         libraries lapack_atlas not found in C:\anaconda3\libs
#       <class 'numpy.distutils.system_info.atlas_threads_info'>
#         NOT AVAILABLE
#
#       atlas_info:
#         libraries f77blas,cblas,atlas not found in C:\anaconda3\lib
#         libraries lapack_atlas not found in C:\anaconda3\lib
#         libraries f77blas,cblas,atlas not found in C:\
#         libraries lapack_atlas not found in C:\
#         libraries f77blas,cblas,atlas not found in C:\anaconda3\libs
#         libraries lapack_atlas not found in C:\anaconda3\libs
#       <class 'numpy.distutils.system_info.atlas_info'>
#         NOT AVAILABLE
#
#       lapack_info:
#         libraries lapack not found in ['C:\\anaconda3\\lib', 'C:\\', 'C:\\anaconda3\\libs']
#         NOT AVAILABLE
#
#       C:\Users\91744\AppData\Local\Temp\pip-install-jv4156t0\numpy_d5224f203bde424bbe44872392394839\numpy\distutils\system_info.py:572: UserWarning:
#           Lapack (http://www.netlib.org/lapack/) libraries not found.
#           Directories to search for the libraries can be specified in the
#           numpy/distutils/site.cfg file (section [lapack]) or by setting
#           the LAPACK environment variable.
#         self.calc_info()
#       lapack_src_info:
#         NOT AVAILABLE
#
#       C:\Users\91744\AppData\Local\Temp\pip-install-jv4156t0\numpy_d5224f203bde424bbe44872392394839\numpy\distutils\system_info.py:572: UserWarning:
#           Lapack (http://www.netlib.org/lapack/) sources not found.
#           Directories to search for the sources can be specified in the
#           numpy/distutils/site.cfg file (section [lapack_src]) or by setting
#           the LAPACK_SRC environment variable.
#         self.calc_info()
#         NOT AVAILABLE
#
#       C:\anaconda3\lib\distutils\dist.py:274: UserWarning: Unknown distribution option: 'define_macros'
#         warnings.warn(msg)
#       running install
#       running build
#       running config_cc
#       unifing config_cc, config, build_clib, build_ext, build commands --compiler options
#       running config_fc
#       unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
#       running build_src
#       build_src
#       building py_modules sources
#       building library "npymath" sources
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#       ----------------------------------------
#   ERROR: Command errored out with exit status 1: 'C:\anaconda3\python.exe' -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\91744\\AppData\\Local\\Temp\\pip-install-jv4156t0\\numpy_d5224f203bde424bbe44872392394839\\setup.py'"'"'; __file__='"'"'C:\\Users\\91744\\AppData\\Local\\Temp\\pip-install-jv4156t0\\numpy_d5224f203bde424bbe44872392394839\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\91744\AppData\Local\Temp\pip-record-zc_ei1pt\install-record.txt' --single-version-externally-managed --prefix 'C:\Users\91744\AppData\Local\Temp\pip-build-env-3y1snzkr\overlay' --compile --install-headers 'C:\Users\91744\AppData\Local\Temp\pip-build-env-3y1snzkr\overlay\Include\numpy' Check the logs for full command output.
#   ----------------------------------------
# ERROR: Command errored out with exit status 1: 'C:\anaconda3\python.exe' 'C:\anaconda3\lib\site-packages\pip' install --ignore-installed --no-user --prefix 'C:\Users\91744\AppData\Local\Temp\pip-build-env-3y1snzkr\overlay' --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- wheel setuptools Cython 'numpy==1.9.3; python_version=='"'"'3.5'"'"'' 'numpy==1.12.1; python_version=='"'"'3.6'"'"'' 'numpy==1.13.1; python_version>='"'"'3.7'"'"'' Check the logs for full command output.

# %%
import pandas as pd

# %%
# %%time
df=pd.read_csv('Mall_Customers.csv')
df.head()
# Out:
# Wall time: 66 ms
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
# %%time
df.groupby('Age')
# Out:
# Wall time: 999 µs

# %%
import modin.pandas as pd
# Out:
# UserWarning: The Dask Engine for Modin is experimental.

# %%
# %%time
df=pd.read_csv('Mall_Customers.csv')
# Out:
# Wall time: 17.2 s

# %%
df.head()
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
# %%time
df.groupby('Age')
# Out:
# Wall time: 30 ms
