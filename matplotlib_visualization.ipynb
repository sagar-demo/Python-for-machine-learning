# %% [markdown]
# ##### MatplotLib Tutorial
# Matplotlib is a plotting library for the Python programming language and its numerical mathematics extension NumPy. It provides an object-oriented API for embedding plots into applications using general-purpose GUI toolkits like Tkinter, wxPython, Qt, or GTK+.
#
# Some of the major Pros of Matplotlib are:
#
# - Generally easy to get started for simple plots
# - Support for custom labels and texts
# - Great control of every element in a figure
# - High-quality output in many formats
# - Very customizable in general

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import numpy as np

# %%
#simple example
x=np.arange(0,20)
y=np.arange(40,60)

# %%
## plotting using matplotlib 


#plt scatter    # this is first function of matplotlib 

plt.scatter(x,y,c='r')
plt.title('Graph in 2D ')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
# Out:
# Text(0, 0.5, 'Y-axis')

# %%
y=x*x

# %%
y
# Out:
# array([  0,   1,   4,   9,  16,  25,  36,  49,  64,  81, 100, 121, 144,
#        169, 196, 225, 256, 289, 324, 361])

# %%
#2 plot # this is 2nd of plotting function
plt.plot(x,y,'r*',linestyle='dashed',linewidth=2,markersize=12)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('2D diagram')
# Out:
# Text(0.5, 1.0, '2D diagram')

# %%
## Creating subplots
plt.subplot(2,2,1)
plt.plot(x,y,'r--')

plt.subplot(2,2,2)
plt.plot(x,y,'g*--')

plt.subplot(2,2,3)
plt.plot(x,y,'b*--')

plt.subplot(2,2,4)
plt.plot(x,y,'r*')

# %%
#### compute the x and y coordinates for points on a sine curve
x=np.arange(0,4*np.pi,0.1)
y=np.sin(x)
plt.title("Since wave form")

# plot the points using matplotlib

plt.plot(x,y)
plt.show()

# %%
import pandas as pd
df=pd.read_csv('kaggle_survey_2020_responses.csv')
df.head()
# Out:
# C:\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   Time from Start to Finish (seconds)                           Q1  \
# 0               Duration (in seconds)  What is your age (# years)?
# 1                                1838                        35-39
# 2                              289287                        30-34
# 3                                 860                        35-39
# 4                                 507                        30-34
#
#                                        Q2  \
# 0  What is your gender? - Selected Choice
# 1                                     Man
# 2                                     Man
# 3                                     Man
# 4                                     Man
#
#                                           Q3  \
# 0  In which country do you currently reside?
# 1                                   Colombia
# 2                   United States of America
# 3                                  Argentina
# 4                   United States of America
#
#                                                   Q4  \
# 0  What is the highest level of formal education ...
# 1                                    Doctoral degree
# 2                                    Master’s degree
# 3                                  Bachelor’s degree
# 4                                    Master’s degree
#
#                                                   Q5  \
# 0  Select the title most similar to your current ...
# 1                                            Student
# 2                                      Data Engineer
# 3                                  Software Engineer
# 4                                     Data Scientist
#
#                                                   Q6  \
# 0  For how many years have you been writing code ...
# 1                                         5-10 years
# 2                                         5-10 years
# 3                                        10-20 years
# 4                                         5-10 years
#
#                                            Q7_Part_1  \
# 0  What programming languages do you use on a reg...
# 1                                             Python
# 2                                             Python
# 3                                                NaN
# 4                                             Python
#
#                                            Q7_Part_2  \
# 0  What programming languages do you use on a reg...
# 1                                                  R
# 2                                                  R
# 3                                                NaN
# 4                                                NaN
#
#                                            Q7_Part_3  ...  \
# 0  What programming languages do you use on a reg...  ...
# 1                                                SQL  ...
# 2                                                SQL  ...
# 3                                                NaN  ...
# 4                                                SQL  ...
#
#                                         Q35_B_Part_2  \
# 0  In the next 2 years, do you hope to become mor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         Q35_B_Part_3  \
# 0  In the next 2 years, do you hope to become mor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         Q35_B_Part_4  \
# 0  In the next 2 years, do you hope to become mor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         Q35_B_Part_5  \
# 0  In the next 2 years, do you hope to become mor...
# 1                                       TensorBoard
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         Q35_B_Part_6  \
# 0  In the next 2 years, do you hope to become mor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         Q35_B_Part_7  \
# 0  In the next 2 years, do you hope to become mor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         Q35_B_Part_8  \
# 0  In the next 2 years, do you hope to become mor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         Q35_B_Part_9  \
# 0  In the next 2 years, do you hope to become mor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                        Q35_B_Part_10  \
# 0  In the next 2 years, do you hope to become mor...
# 1                                                NaN
# 2                                                NaN
# 3                                               None
# 4                                                NaN
#
#                                          Q35_B_OTHER
# 0  In the next 2 years, do you hope to become mor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 355 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20037 entries, 0 to 20036
# Columns: 355 entries, Time from Start to Finish (seconds) to Q35_B_OTHER
# dtypes: object(355)
# memory usage: 27.1+ MB

# %%
df.describe()
# Out:
#         Time from Start to Finish (seconds)     Q1     Q2     Q3  \
# count                                 20037  20037  20037  20037
# unique                                 5168     12      6     56
# top                                     565  25-29    Man  India
# freq                                     34   4011  15789   5851
#
#                      Q4       Q5         Q6 Q7_Part_1 Q7_Part_2 Q7_Part_3  \
# count             19570    19278      19121     15531      4278      7536
# unique                8       14          8         2         2         2
# top     Master’s degree  Student  3-5 years    Python         R       SQL
# freq               7859     5171       4546     15530      4277      7535
#
#         ...        Q35_B_Part_2 Q35_B_Part_3          Q35_B_Part_4  \
# count   ...                1178          495                   431
# unique  ...                   2            2                     2
# top     ...   Weights & Biases     Comet.ml    Sacred + Omniboard
# freq    ...                1177          494                   430
#
#          Q35_B_Part_5 Q35_B_Part_6 Q35_B_Part_7 Q35_B_Part_8  \
# count            3200          558          481          847
# unique              2            2            2            2
# top      TensorBoard     Guild.ai     Polyaxon       Trains
# freq             3199          557          480          846
#
#                   Q35_B_Part_9 Q35_B_Part_10 Q35_B_OTHER
# count                      520          3083         252
# unique                       2             2           2
# top      Domino Model Monitor           None       Other
# freq                       519          3082         251
#
# [4 rows x 355 columns]

# %%
### Bar plot
plt.bar(df['Q1'],df['Q2'])
plt.title('Bar Graph')
plt.xlabel('Q1')
plt.ylabel('Q2')
# Out:
# Text(0, 0.5, 'Q2')

# %%
### Histograms
plt.hist(df['Q1'])
plt.title('Histogram')
plt.show()

# %%
####Box Plot using Matplotlib
data = [np.random.normal(0, std, 100) for std in range(1, 4)]

# rectangular box plot
plt.boxplot(data,vert=True,patch_artist=False);

# %%
data
# Out:
# [array([-0.23331363,  0.98106321, -1.33005353, -1.65563634,  0.60168287,
#          1.10151864, -0.25042591,  0.65269178, -0.91515565, -0.91437059,
#         -0.67792405, -0.99055834,  1.64453958,  1.36142466, -0.96706695,
#         -1.31466086,  0.11656885,  0.17682321,  0.61056658, -0.24827496,
#          1.75151871,  0.90887284,  1.6567532 , -0.85417248,  0.53629548,
#         -0.36366613,  0.74763439,  0.77094763,  1.41136697,  1.16357811,
#          0.49971957,  0.8346798 ,  0.16807019, -1.25884737, -0.0743843 ,
#          1.09247865, -0.29977008,  0.91096751,  1.28310171,  0.65713559,
#         -1.64419582,  1.02963063, -0.43569913,  1.25564161,  0.09657421,
#         -1.02410173,  1.36338916,  1.57216757, -0.32659683,  0.51773362,
#         -1.59373714, -0.30693016, -0.52800697, -0.40698007, -0.22148828,
#          1.82672131, -0.9680485 ,  0.79389113,  0.73169001, -0.82163552,
#          1.04779145, -0.98075545, -0.76623072,  0.14170953, -0.79048305,
#         -0.4853404 ,  1.03032568, -0.20697306, -0.86069722,  0.41654361,
#         -0.70178394,  0.89963291, -1.00069741, -0.17145626,  0.75925154,
#          0.31303044, -0.63205589,  0.45388504, -1.09084016,  0.274976  ,
#         -0.44874571, -0.51554962,  0.0981862 ,  0.7260448 , -0.2680132 ,
#          0.33464199, -0.25034642,  0.4834157 ,  0.60558299,  1.53537523,
#         -0.04242536,  0.13658344, -2.29518095,  1.61667185,  0.70598824,
#          2.41507076,  0.79731786,  0.41867981,  0.4144862 ,  0.63216909]),
#  array([ 1.34669772, -0.09445002, -0.84273285,  2.06719683,  0.25454469,
#          1.45320146, -3.14070457, -3.21637463,  0.19484149,  2.11254348,
